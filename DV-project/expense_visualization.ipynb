# %% [markdown]
# # 📊 Construction Spending Dashboard
# This notebook provides an interactive dashboard for analyzing financial data from two projects: **House** and **Studio**.
#
# Use the widgets below to filter and explore insights from the dataset.

# %%
#expenses.py

# %%
# --- DATA ENTRY ---
house_data =[    
    # JANUARY
    {"date": "2025-01-04", "amount": 12500, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-01-08", "amount": 7400, "given_to": "Cement", "payment_mode": "online", "paid_by": "Badi Maa"},
    {"date": "2025-01-12", "amount": 1800, "given_to": "Tea Snacks", "payment_mode": "cash", "paid_by": "Sunny"},
    {"date": "2025-01-16", "amount": 6200, "given_to": "Tiles", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-01-19", "amount": 3300, "given_to": "Bricks", "payment_mode": "cash", "paid_by": "Sunny"},
    {"date": "2025-01-23", "amount": 24000, "given_to": "Truck Service", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-01-27", "amount": 1500, "given_to": "Pipes", "payment_mode": "cash", "paid_by": "Divyan"},
    {"date": "2025-01-30", "amount": 5000, "given_to": "Labour", "payment_mode": "cash", "paid_by": "Sunny Salary"},

    # FEBRUARY
    {"date": "2025-02-02", "amount": 9500, "given_to": "Sand", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-02-05", "amount": 3700, "given_to": "Rodi", "payment_mode": "cash", "paid_by": "Sunny"},
    {"date": "2025-02-09", "amount": 11000, "given_to": "Shuttering", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-02-13", "amount": 2600, "given_to": "Paint", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-02-16", "amount": 4000, "given_to": "Pipe Fittings", "payment_mode": "online", "paid_by": "Sunny"},
    {"date": "2025-02-20", "amount": 7300, "given_to": "Electricity Tools", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-02-24", "amount": 2900, "given_to": "Safety Helmets", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-02-28", "amount": 15000, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Sunny Salary"},

    # MARCH
    {"date": "2025-03-01", "amount": 6100, "given_to": "Wire", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-03-05", "amount": 8700, "given_to": "Truck Fuel", "payment_mode": "online", "paid_by": "Sunny"},
    {"date": "2025-03-09", "amount": 3000, "given_to": "Pipe", "payment_mode": "cash", "paid_by": "Divyan"},
    {"date": "2025-03-11", "amount": 13000, "given_to": "RMC", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-03-15", "amount": 2400, "given_to": "Paint Brushes", "payment_mode": "online", "paid_by": "Sunny"},
    {"date": "2025-03-19", "amount": 9800, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-03-24", "amount": 4100, "given_to": "Drill Rental", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-03-29", "amount": 5500, "given_to": "Cement", "payment_mode": "cash", "paid_by": "Mummy"},

    # APRIL
    {"date": "2025-04-02", "amount": 7800, "given_to": "Shuttering", "payment_mode": "online", "paid_by": "Sunny"},
    {"date": "2025-04-06", "amount": 4200, "given_to": "Tea Snacks", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-04-10", "amount": 8900, "given_to": "Bricks", "payment_mode": "cash", "paid_by": "Sunny"},
    {"date": "2025-04-14", "amount": 3600, "given_to": "Pipe", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-04-18", "amount": 21500, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-04-20", "amount": 9000, "given_to": "Truck Rent", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-04-25", "amount": 1200, "given_to": "Tools Repair", "payment_mode": "cash", "paid_by": "Sunny"},
    {"date": "2025-04-29", "amount": 15000, "given_to": "Labour", "payment_mode": "cash", "paid_by": "Sunny Salary"},

    # May 2025
    {"date": "2025-05-19", "amount": 12000, "given_to": "Bajri", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-05-20", "amount": 7000, "given_to": "Rodi", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-05-21", "amount": 50000, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-05-23", "amount": 93000, "given_to": "Brick", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-05-25", "amount": 20000, "given_to": "Truck Driver", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-05-25", "amount": 29000, "given_to": "Truck Driver", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-05-25", "amount": 9000, "given_to": "Labour", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-05-23", "amount": 104000, "given_to": "Bajri", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-05-29", "amount": 20000, "given_to": "Ashok (SBI Loan Acc)", "payment_mode": "online", "paid_by": "Mummy "},
    {"date": "2025-05-30", "amount": 1000, "given_to": "Water", "payment_mode": "cash", "paid_by": "Mummy"},
    # June 2025
    {"date": "2025-06-01", "amount": 10000, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-06-03", "amount": 40000, "given_to": "Ganesh", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-06-03", "amount": 7000, "given_to": "Mangilal (Malba Pickup)", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-06-04", "amount": 1400, "given_to": "AC Fitting", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-06-04", "amount": 5600, "given_to": "Car Service", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-06-05", "amount": 31800, "given_to": "RMC", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-05", "amount": 2000, "given_to": "Ladder and Matki", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-06", "amount": 8000, "given_to": "Motor", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-06-06", "amount": 1200, "given_to": "Pipe", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-06-07", "amount": 800, "given_to": "Plumbing Equipment", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-07", "amount": 400, "given_to": "Wire", "payment_mode": "online", "paid_by": "Divyan"},
    {"date": "2025-06-08", "amount": 7000, "given_to": "Rodi", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-08", "amount": 1500, "given_to": "Plumbing Equipment", "payment_mode": "cash", "paid_by": "Sunny Salary"},
]

studio_data =[    
    # January 2025
    {'date': '2025-01-05', 'amount': 42661, 'given_to': 'Cement Vendor', 'payment_mode': 'online', 'paid_by': 'Mummy'},
    {'date': '2025-01-11', 'amount': 99650, 'given_to': 'AC Technician', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-01-13', 'amount': 92058, 'given_to': 'Cement Vendor', 'payment_mode': 'online', 'paid_by': 'Mummy'},
    {'date': '2025-01-17', 'amount': 77130, 'given_to': 'Paint Shop', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-01-19', 'amount': 98843, 'given_to': 'Electrician', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-01-21', 'amount': 87463, 'given_to': 'Cement Vendor', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-01-26', 'amount': 74670, 'given_to': 'Furnace Guy', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-01-27', 'amount': 28295, 'given_to': 'Furnace Guy', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},

    # February 2025
    {'date': '2025-02-01', 'amount': 99630, 'given_to': 'AC Technician', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-02-04', 'amount': 61602, 'given_to': 'Wood Supplier', 'payment_mode': 'online', 'paid_by': 'Sunny Salary'},
    {'date': '2025-02-08', 'amount': 63279, 'given_to': 'Paint Shop', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-02-09', 'amount': 57371, 'given_to': 'Tiles Vendor', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-02-12', 'amount': 35413, 'given_to': 'Electrician', 'payment_mode': 'online', 'paid_by': 'Sunny Salary'},
    {'date': '2025-02-17', 'amount': 76176, 'given_to': 'Tiles Vendor', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-02-20', 'amount': 94940, 'given_to': 'Tiles Vendor', 'payment_mode': 'cash', 'paid_by': 'Mummy'},
    {'date': '2025-02-25', 'amount': 13297, 'given_to': 'Tiles Vendor', 'payment_mode': 'online', 'paid_by': 'Mummy'},

    # March 2025
    {'date': '2025-03-01', 'amount': 33185, 'given_to': 'Electrician', 'payment_mode': 'online', 'paid_by': 'Divyan'},
    {'date': '2025-03-02', 'amount': 39747, 'given_to': 'Furnace Guy', 'payment_mode': 'cash', 'paid_by': 'Mummy'},
    {'date': '2025-03-06', 'amount': 55838, 'given_to': 'AC Technician', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-03-07', 'amount': 31140, 'given_to': 'Plumber', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-03-12', 'amount': 84132, 'given_to': 'Paint Shop', 'payment_mode': 'cash', 'paid_by': 'Mummy'},
    {'date': '2025-03-17', 'amount': 22179, 'given_to': 'Wood Supplier', 'payment_mode': 'online', 'paid_by': 'Mummy'},
    {'date': '2025-03-23', 'amount': 46952, 'given_to': 'Tiles Vendor', 'payment_mode': 'online', 'paid_by': 'Sunny Salary'},
    {'date': '2025-03-26', 'amount': 81283, 'given_to': 'Electrician', 'payment_mode': 'cash', 'paid_by': 'Mummy'},

    # April 2025
    {'date': '2025-04-02', 'amount': 24414, 'given_to': 'Cement Vendor', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-04-04', 'amount': 97539, 'given_to': 'Tiles Vendor', 'payment_mode': 'online', 'paid_by': 'Divyan'},
    {'date': '2025-04-06', 'amount': 87380, 'given_to': 'AC Technician', 'payment_mode': 'online', 'paid_by': 'Mummy'},
    {'date': '2025-04-09', 'amount': 58073, 'given_to': 'Plumber', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-04-13', 'amount': 44593, 'given_to': 'Electrician', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {'date': '2025-04-18', 'amount': 17513, 'given_to': 'Wood Supplier', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-04-22', 'amount': 77311, 'given_to': 'Electrician', 'payment_mode': 'cash', 'paid_by': 'Divyan'},
    {'date': '2025-04-26', 'amount': 42029, 'given_to': 'Tiles Vendor', 'payment_mode': 'cash', 'paid_by': 'Sunny Salary'},
    {"date": "2025-04-29", "amount": 118000, "given_to": "Sthapatya", "payment_mode": "cheque", "paid_by": "Sunny"},
    # May 2025
    {"date": "2025-05-06", "amount": 59000, "given_to": "Mayank", "payment_mode": "cheque", "paid_by": "Papa"},
    {"date": "2025-05-07", "amount": 250000, "given_to": "Mayank", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-05-09", "amount": 781429, "given_to": "JDA", "payment_mode": "online", "paid_by": "Papa"},
    {"date": "2025-05-16", "amount": 19600, "given_to": "SBI file charge", "payment_mode": "online", "paid_by": "Papa"},
    {"date": "2025-05-19", "amount": 200000, "given_to": "Mayank", "payment_mode": "cash", "paid_by": "Prem Mausi"},
    {"date": "2025-05-21", "amount": 100000, "given_to": "Mayank", "payment_mode": "cash", "paid_by": "Badi Maa"},
    {"date": "2025-05-21", "amount": 34000, "given_to": "JDA", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-05-27", "amount": 172700, "given_to": "SBI stamp duty", "payment_mode": "cheque", "paid_by": "Parul Construction"},
    {"date": "2025-05-27", "amount": 20000, "given_to": "Mangilal", "payment_mode": "cash", "paid_by": "SBI loan acc"},
    {"date": "2025-05-27", "amount": 150000, "given_to": "Sitaram", "payment_mode": "cash", "paid_by": "SBI loan acc"},
    {"date": "2025-05-28", "amount": 4500, "given_to": "tent house", "payment_mode": "cash", "paid_by": "SBI loan acc"},
    {"date": "2025-05-28", "amount": 7500, "given_to": "muhurat", "payment_mode": "cash", "paid_by": "SBI loan acc"},
    {"date": "2025-05-30", "amount": 8000, "given_to": "electricity demand notice", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-05-30", "amount": 20000, "given_to": "Sunny", "payment_mode": "online", "paid_by": "Papa"},
    # June 2025
    {"date": "2025-06-02", "amount": 5400, "given_to": "boring", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-02", "amount": 2900, "given_to": "wire", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-02", "amount": 4300, "given_to": "basement sheets", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-02", "amount": 44000, "given_to": "building insurance", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-06-02", "amount": 44000, "given_to": "building insurance", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-03", "amount": 2500, "given_to": "labour pipe shift", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-06-03", "amount": 2500, "given_to": "plumbing equipment", "payment_mode": "cash", "paid_by": "Mummy"},
    {"date": "2025-06-04", "amount": 1400, "given_to": "Shankar electricity", "payment_mode": "online", "paid_by": "Mummy"},
    {"date": "2025-06-06", "amount": 2500, "given_to": "trolly Mangilal", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-06", "amount": 4000, "given_to": "termite meds", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-09", "amount": 1200, "given_to": "green sheets", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-09", "amount": 9000, "given_to": "sin sheet", "payment_mode": "online", "paid_by": "SBI loan acc"},
    {"date": "2025-06-09", "amount": 1000, "given_to": "Shibu", "payment_mode": "cash", "paid_by": "Sunny Salary"},
    {"date": "2025-06-11", "amount": 7100, "given_to": "gitti", "payment_mode": "online", "paid_by": "SBI loan acc"}
]

# %%
# --- INITIALIZATION ---

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import ipywidgets as widgets
from ipywidgets import interact_manual, HBox, HTML, VBox, Button
from IPython.display import display, clear_output
import calendar
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

plt.style.use('ggplot')
sns.set_palette("Set2")

# %%
# --- Formatter ---
def inr(x, _): return f"₹{x:,.0f}"
currency_fmt = FuncFormatter(inr)

# %%
# Normalize all paid_by entries
for data in (house_data, studio_data):
    for row in data:
        row['paid_by'] = row['paid_by'].strip().title().replace('  ', ' ')

# %%
# Convert to DataFrame
house_df = pd.DataFrame(house_data)
studio_df = pd.DataFrame(studio_data)

for df in (house_df, studio_df):
    df['date'] = pd.to_datetime(df['date'])
    df['month'] = df['date'].dt.month_name()
    df['day'] = df['date'].dt.day_name()

summary_df = pd.concat([
    house_df.assign(Project='House'),
    studio_df.assign(Project='Studio')
])

# %%
# --- Chart Function ---
def plot_chart(df, group, chart_type, title):
    agg = df.groupby(group)['amount'].sum().sort_values(ascending=False)

    if chart_type == "Bar Chart":
        plt.figure()
        ax = agg.plot(kind='bar', figsize=(max(9, len(agg) * 0.5), 4))
        ax.yaxis.set_major_formatter(currency_fmt)
        plt.title(title)
        plt.tight_layout()
        plt.show()

    elif chart_type == "Pie Chart":
        plt.figure()
        plt.pie(agg, labels=agg.index, autopct='%1.1f%%', startangle=140)
        plt.axis('equal')
        plt.title(title)
        plt.tight_layout()
        plt.show()

    elif chart_type == "Trend Line":
        trend_df = df.groupby('date')['amount'].sum()
        trend_df.plot(marker='o')
        plt.gca().yaxis.set_major_formatter(currency_fmt)
        plt.title("Spending Over Time")
        plt.xlabel("Date")
        plt.ylabel("Amount")
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    elif chart_type == "Top Contributors":
        top_df = df.groupby('paid_by')['amount'].sum().sort_values(ascending=False).head(10)
        top_df.plot(kind='bar')
        plt.title("Top Contributors")
        plt.gca().yaxis.set_major_formatter(currency_fmt)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    elif chart_type == "Heatmap":
        heat_df = df.groupby(['day', 'month'])['amount'].sum().unstack(fill_value=0)
        plt.figure(figsize=(12, 6))
        sns.heatmap(heat_df, annot=True, fmt='.0f', cmap='YlGnBu')
        plt.title("Weekly Heatmap")
        plt.tight_layout()
        plt.show()

    elif chart_type == "Summary Table":
        summary = df.groupby(group)['amount'].sum().reset_index().sort_values(by='amount', ascending=False)
        styled = summary.style.format({'amount': '₹{:,.0f}'}).set_caption("Summary Table")
        display(styled)

# %%
# --- Show Raw Data ---
def show_data_table():
    if summary_df.empty:
        display(HTML("<p style='color:red;'>No data available.</p>"))
    else:
        display(HTML("<h4>Raw Data Table</h4>"))
        display(summary_df.sort_values(by='date').reset_index(drop=True).style.format({'amount': '₹{:,.0f}'}))

# %%
# --- Dashboard ---
def run_dashboard():
    chart_selector = widgets.Dropdown(
        options=['Bar Chart', 'Pie Chart', 'Trend Line', 'Top Contributors', 'Heatmap', 'Summary Table'],
        value='Bar Chart', description='Chart Type:'
    )
    group_selector = widgets.Dropdown(
        options=['given_to', 'paid_by', 'payment_mode', 'day', 'month'],
        value='month', description='Group By:'
    )
    month_selector = widgets.Dropdown(
        options=['All'] + sorted(summary_df['month'].unique()),
        value='All', description='Month:'
    )
    mode_selector = widgets.Dropdown(
        options=['All'] + sorted(summary_df['payment_mode'].dropna().unique()),
        value='All', description='Mode:'
    )
    source_selector = widgets.Dropdown(
        options=['All'] + sorted(summary_df['Project'].unique()),
        value='All', description='Source:'
    )

    output = widgets.Output()

    def filter_data():
        df = summary_df.copy()
        if month_selector.value != 'All':
            df = df[df['month'] == month_selector.value]
        if mode_selector.value != 'All':
            df = df[df['payment_mode'] == mode_selector.value]
        if source_selector.value != 'All':
            df = df[df['Project'] == source_selector.value]
        return df

    def update_chart(change):
        with output:
            clear_output(wait=True)
            df = filter_data()
            plot_chart(df, group_selector.value, chart_selector.value, 'Filtered View')

    for widget in [chart_selector, group_selector, month_selector, mode_selector, source_selector]:
        widget.observe(update_chart, names='value')

    display(VBox([
        HBox([chart_selector, group_selector]),
        HBox([month_selector, mode_selector, source_selector]),
        output
    ]))

    update_chart(None)

# %%
# --- Dashboard ---
if not summary_df.empty:
    display(HTML("<h3>Total Spending Summary</h3>"))
    total_summary = summary_df.groupby('Project')['amount'].sum().reset_index()
    total_value = summary_df['amount'].sum()
    display(total_summary.style.format({'amount': '₹{:,.0f}'}).set_caption("Total by Project"))
    display(HTML(f"<h4>Grand Total: ₹{total_value:,.0f}</h4>"))

    display(HTML("<hr><h3>Interactive Dashboard</h3>"))
    run_dashboard()
else:
    print("No data loaded. Please verify house_data and studio_data.")
# Out:
# HTML(value='<h3>Total Spending Summary</h3>')
# <style type="text/css">
# </style>
# <table id="T_11d67">
#   <caption>Total by Project</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11d67_level0_col0" class="col_heading level0 col0" >Project</th>
#       <th id="T_11d67_level0_col1" class="col_heading level0 col1" >amount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11d67_row0_col0" class="data row0 col0" >House</td>
#       <td id="T_11d67_row0_col1" class="data row0 col1" >₹703,200</td>
#     </tr>
#     <tr>
#       <th id="T_11d67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11d67_row1_col0" class="data row1 col0" >Studio</td>
#       <td id="T_11d67_row1_col1" class="data row1 col1" >₹4,022,315</td>
#     </tr>
#   </tbody>
# </table>
# HTML(value='<h4>Grand Total: ₹4,725,515</h4>')
# ...
